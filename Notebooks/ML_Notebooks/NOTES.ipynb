# %% [markdown]
# # Notes
#
#
# You need to double check the ML_Ready_Data for proper columns.
#
# Here is the top features ranked by standard deviation.
# -------------------------------------------------------
#   molecular_weight                     99.0381    ★  TOP
#   aliphatic_index                      49.6424    ★  TOP
#   instability_index                    39.2929    ★  TOP
#   aa_pct_L                             10.8626    ★  TOP
#   aa_pct_A                              9.2339    ★  TOP
#   aa_pct_V                              8.9592    ★  TOP
#   aa_pct_S                              8.5508    ★  TOP
#   aa_pct_E                              8.3739    ★  TOP
#   aa_pct_I                              7.9161
#   aa_pct_P                              7.8996
#   aa_pct_T                              7.6668
#   aa_pct_F                              7.5753
#   aa_pct_K                              7.5089
#   aa_pct_R                              7.3580
#   aa_pct_Y                              7.0971
#   aa_pct_Q                              7.0065
#   aa_pct_G                              6.9881
#   aa_pct_D                              6.1766
#   aa_pct_N                              5.9014
#   aa_pct_H                              5.2582
#   aa_pct_M                              4.7609
#   aa_pct_W                              3.7664
#   isoelectric_point                     2.3018
#   aa_pct_C                              2.1028
#   tcr_contact_hydro_mean                1.4412
#   charge_pH_7                           1.3174
#   hydrophobicity_GRAVY                  0.9375
#   tcr_hydrophobic_count                 0.9271
#   tcr_aromatic_count                    0.6406
#   boman_index                           0.5644
#   has_aromatic_central                  0.4845
#   has_tryptophan                        0.3122
#   tryptophan_at_tcr_pos                 0.1966
#   helix_fraction                        0.1685
#   hla_population_freq                   0.1534
#   sheet_fraction                        0.1477
#   hydrophobic_fraction                  0.1468
#   turn_fraction                         0.1400
#   aromaticity                           0.1054
#   flexibility_mean                      0.0255
#
# Top 8 selected features:
#   ✓  molecular_weight  (SD = 99.0381)
#   ✓  aliphatic_index  (SD = 49.6424)
#   ✓  instability_index  (SD = 39.2929)
#   ✓  aa_pct_L  (SD = 10.8626)
#   ✓  aa_pct_A  (SD = 9.2339)
#   ✓  aa_pct_V  (SD = 8.9592)
#   ✓  aa_pct_S  (SD = 8.5508)
#   ✓  aa_pct_E  (SD = 8.3739)
